# %%
# !pip install -U spacy
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 130.9 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("es_core_news_sm")

# %%
import spacy
from random import choice
from time import sleep

# Cargar modelos en español e inglés
nlp_es = spacy.load("es_core_news_sm")
nlp_en = spacy.load("en_core_web_sm")

# Diccionario de síntomas a especialidades (básico y expandible)
especialidades = {
    "dolor de cabeza": "neurología",
    "fiebre": "medicina interna",
    "pecho": "cardiología",
    "corazón": "cardiología",
    "abdomen": "gastroenterología",
    "pierna": "ortopedia",
    "pulmones": "neumología",
    "depresión": "psiquiatría",
    "visión": "oftalmología",
    "respirar": "neumología",
    "fractura": "traumatología",
    "corte": "urgencias",
    "infección": "infectología",
    "embarazo": "ginecología",
    "piel": "dermatología",
    "estómago": "gastroenterología",
    "ansiedad": "psiquiatría",
    "sangrado": "emergencias"
}

# Hospitales premium por país
hospitales = {
    "mexico": ["Hospital Ángeles del Pedregal", "Médica Sur", "Hospital Español", "Star Médica"],
    "usa": ["Mayo Clinic", "Cleveland Clinic", "Mount Sinai"],
    "francia": ["Hôpital Necker", "Pitié-Salpêtrière", "Clinique Ambroise Paré"],
    "japon": ["St. Luke's International Hospital", "Tokyo Medical University Hospital"],
    "colombia": ["Fundación Santa Fe", "Clínica del Country"]
}

# Simulación de aseguradora
aseguradora_aprobada = ["AXA", "GNP", "MetLife"]

# Simulación de IA para clasificar síntomas
def detectar_especialidad(texto, idioma="es"):
    nlp = nlp_es if idioma == "es" else nlp_en
    doc = nlp(texto.lower())
    for token in doc:
        for sintoma in especialidades:
            if sintoma in token.text:
                return especialidades[sintoma]
    return "medicina general"

# --- Simulación de conversación ---

print("🤖 Asistente Médico Premium - IA de Clasificación de Emergencias\n")
idioma = input("Idioma / Language? (es/en): ").strip().lower()
nombre = input("👤 ¿Cuál es tu nombre?: ")
ubicacion = input("📍 ¿En qué país estás?: ").strip().lower()
hospital = choice(hospitales.get(ubicacion, ["Hospital General Premium"]))
sintomas = input("📝 Describe qué síntomas tienes o qué pasó: ")

print("\n🧠 Analizando tu situación con IA...")
sleep(1.5)
especialista = detectar_especialidad(sintomas, idioma)

print(f"\n✅ {nombre}, basado en tu mensaje te sugerimos un especialista en *{especialista}*.")

# Verificación de aseguradora
aseguradora = input("🏥 ¿Cuál es tu aseguradora?: ").strip()
print("🔍 Verificando aseguradora con red hospitalaria...")
sleep(2)

if aseguradora.lower() in [a.lower() for a in aseguradora_aprobada]:
    medico = f"Dr. {choice(['Juan Pérez', 'Laura Gómez', 'Andrés Ríos', 'Elena Martínez'])}"
    print(f"✅ Aseguradora verificada. El {medico} te atenderá en *{hospital}*.\n")
else:
    print("❌ Tu aseguradora no está verificada. Por favor paga en recepción o contacta soporte.")

# Opción de contacto
llamada = input("📞 ¿Deseas que un asesor te llame? (sí/no): ").strip().lower()
if llamada in ["sí", "si", "yes"]:
    print("📲 En breve un asesor humano te llamará. Gracias por confiar en nosotros.")
else:
    print("📨 Puedes continuar tu atención vía WhatsApp o agendar otra cita más adelante.")
# Out:
# 🤖 Asistente Médico Premium - IA de Clasificación de Emergencias
#
# Idioma / Language? (es/en): es
# 👤 ¿Cuál es tu nombre?: Axel
# 📍 ¿En qué país estás?: México
# 📝 Describe qué síntomas tienes o qué pasó: mi hijo se cayó de las escaleras, esta sangrando
#
# 🧠 Analizando tu situación con IA...
#
# ✅ Axel, basado en tu mensaje te sugerimos un especialista en *medicina general*.
# 🏥 ¿Cuál es tu aseguradora?: GNP
# 🔍 Verificando aseguradora con red hospitalaria...
# ✅ Aseguradora verificada. El Dr. Laura Gómez te atenderá en *Hospital General Premium*.
#
# 📞 ¿Deseas que un asesor te llame? (sí/no): si
# 📲 En breve un asesor humano te llamará. Gracias por confiar en nosotros.
