# %%
import json

# Estructura de chatbot avanzada para el Notebook 3: Motor de conversación Flask + IA
chatbot_config = {
    "version": "3.0",
    "idiomas_soportados": ["español", "inglés", "francés", "portugués"],
    "flujo_principal": {
        "saludo": {
            "triggers": ["hola", "hi", "bonjour", "oi"],
            "respuesta": {
                "español": "Hola 👋, soy tu asistente médico premium 🤖. ¿Qué necesitas?",
                "inglés": "Hello 👋, I'm your premium medical assistant 🤖. How can I help you?",
                "francés": "Bonjour 👋, je suis votre assistant médical premium 🤖. Que puis-je faire pour vous?",
                "portugués": "Olá 👋, sou seu assistente médico premium 🤖. Em que posso te ajudar?"
            },
            "opciones": [
                "Tengo una emergencia 🚨",
                "Agendar una cita 📅",
                "Ver hospitales cercanos 🏥",
                "Hablar con un asesor humano 👨‍⚕️",
                "Consulta por síntomas 🤒",
                "Información sobre mi aseguradora 🛡️",
                "Soporte internacional 🌎"
            ]
        },
        "emergencia": {
            "triggers": ["emergencia", "auxilio", "urgente", "emergency"],
            "pasos": [
                "¿Dónde estás ubicado? (País / Ciudad)",
                "¿Qué tipo de emergencia estás experimentando?",
                "¿Deseas que asignemos un hospital cercano automáticamente?",
                "Verificando disponibilidad hospitalaria y con aseguradora...",
                "Confirmado ✅: Te atenderá el Dr. ____, especialista en ____ en el hospital ____."
            ]
        },
        "sintomas": {
            "triggers": ["me duele", "síntomas", "dolor", "malestar", "problema"],
            "modelo_IA": "GPT-SYMPTOM-MATCHER",
            "respuesta": "Gracias por describir tus síntomas. Estoy analizando... ⏳\n\n🧠 Diagnóstico preliminar: podrías requerir un especialista en {especialidad}.\n¿Quieres que busque hospitales con disponibilidad?"
        },
        "aseguradora": {
            "triggers": ["aseguradora", "seguro médico", "póliza"],
            "pasos": [
                "¿Cuál es el nombre de tu aseguradora?",
                "Verificando validez de la póliza...",
                "✅ Póliza activa. Se cubrirá la atención médica en centros certificados.",
                "❌ Póliza no encontrada. ¿Deseas ayuda para validar con un asesor?"
            ]
        },
        "llamada_directa": {
            "triggers": ["quiero llamar", "llamar", "teléfono"],
            "respuesta": "Puedes comunicarte directamente marcando al 📞 +52-800-123-4567. Un asesor humano te atenderá 24/7."
        }
    },
    "especialidades_medicas": [
        "Cardiología", "Neurología", "Pediatría", "Traumatología", "Dermatología", "Psiquiatría",
        "Medicina Interna", "Gastroenterología", "Urología", "Oncología"
    ],
    "integracion_con_hospitales": {
        "soporte_gps": True,
        "comunicacion_en_red": True,
        "disponibilidad_horaria_en_tiempo_real": True
    },
    "seguridad": {
        "nivel_encriptacion": "AES-256",
        "autenticacion_2factores": True,
        "cumple_HIPAA": True
    }
}

with open("/mnt/data/estructura_chatbot_avanzada.json", "w") as f:
    json.dump(chatbot_config, f, indent=2)

import ace_tools as tools; tools.display_dataframe_to_user(name="Estructura de Conversación Chatbot Avanzado", dataframe=None)
