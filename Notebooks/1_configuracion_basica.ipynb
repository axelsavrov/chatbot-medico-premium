# %%
import json

# Estructura avanzada de configuración de hospitales premium por continente, país y ciudad
hospitales_config = {
    "América del Norte": {
        "México": {
            "CDMX": [
                "Hospital Ángeles del Pedregal",
                "Hospital ABC",
                "Hospital Español",
                "Médica Sur",
                "Star Médica Centro"
            ],
            "Monterrey": [
                "Hospital San José TecSalud",
                "Christus Muguerza Alta Especialidad"
            ],
            "Guadalajara": [
                "Hospital Puerta de Hierro",
                "Hospital Ángeles del Carmen"
            ]
        },
        "Estados Unidos": {
            "Nueva York": [
                "Mount Sinai Hospital",
                "NewYork-Presbyterian",
                "NYU Langone Health"
            ],
            "Boston": [
                "Massachusetts General Hospital",
                "Brigham and Women's Hospital"
            ],
            "Rochester": [
                "Mayo Clinic"
            ]
        },
        "Canadá": {
            "Toronto": [
                "Toronto General Hospital",
                "Sunnybrook Health Sciences Centre"
            ],
            "Vancouver": [
                "Vancouver General Hospital"
            ]
        }
    },
    "América del Sur": {
        "Brasil": {
            "São Paulo": [
                "Hospital Israelita Albert Einstein",
                "Hospital Sírio-Libanês"
            ]
        },
        "Argentina": {
            "Buenos Aires": [
                "Hospital Italiano",
                "Sanatorio Güemes"
            ]
        },
        "Chile": {
            "Santiago": [
                "Clínica Alemana",
                "Clínica Las Condes"
            ]
        },
        "Colombia": {
            "Bogotá": [
                "Fundación Santa Fe de Bogotá",
                "Clínica del Country"
            ]
        }
    },
    "Europa": {
        "Francia": {
            "París": [
                "Hôpital Pitié-Salpêtrière",
                "Hôpital Necker-Enfants Malades"
            ]
        },
        "España": {
            "Madrid": [
                "Hospital Ruber Internacional",
                "Clínica Universidad de Navarra"
            ]
        },
        "Reino Unido": {
            "Londres": [
                "The London Clinic",
                "Royal Marsden Hospital"
            ]
        },
        "Alemania": {
            "Berlín": [
                "Charité – Universitätsmedizin Berlin"
            ]
        }
    },
    "Asia": {
        "Japón": {
            "Tokio": [
                "The University of Tokyo Hospital",
                "St. Luke’s International Hospital"
            ]
        },
        "Corea del Sur": {
            "Seúl": [
                "Seoul National University Hospital",
                "Asan Medical Center"
            ]
        },
        "India": {
            "Delhi": [
                "All India Institute of Medical Sciences (AIIMS)",
                "Fortis Escorts Heart Institute"
            ]
        }
    },
    "Medio Oriente": {
        "Emiratos Árabes Unidos": {
            "Dubái": [
                "Cleveland Clinic Abu Dhabi",
                "American Hospital Dubai"
            ]
        },
        "Arabia Saudita": {
            "Riad": [
                "King Faisal Specialist Hospital"
            ]
        }
    },
    "África": {
        "Sudáfrica": {
            "Ciudad del Cabo": [
                "Groote Schuur Hospital",
                "Netcare Christiaan Barnard Memorial Hospital"
            ]
        },
        "Nigeria": {
            "Lagos": [
                "Reddington Hospital",
                "Lagoon Hospitals"
            ]
        }
    }
}

# Guardar en archivo JSON
output_path = "/mnt/data/hospitales_config.json"
with open(output_path, "w") as f:
    json.dump(hospitales_config, f, indent=2)

output_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1-1255378078.py in <cell line: 0>()
#     147 # Guardar en archivo JSON
#     148 output_path = "/mnt/data/hospitales_config.json"
# --> 149 with open(output_path, "w") as f:
#     150     json.dump(hospitales_config, f, indent=2)
#     151
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/hospitales_config.json'
