# %%
from pathlib import Path
import json

# Estructura extremadamente avanzada y escalable de paciente para el Notebook 2
estructura_paciente = {
    "id_paciente": "string",
    "nombre_completo": "string",
    "edad": "int",
    "genero": "string",
    "telefono": "string",
    "email": "string",
    "direccion": {
        "pais": "string",
        "estado": "string",
        "ciudad": "string",
        "codigo_postal": "string"
    },
    "historial_medico": {
        "enfermedades_previas": ["string"],
        "alergias": ["string"],
        "cirugias_previas": ["string"],
        "medicamentos_actuales": ["string"],
        "vacunas": ["string"]
    },
    "datos_seguro": {
        "aseguradora": "string",
        "numero_poliza": "string",
        "vigencia": "string",
        "nivel_cobertura": "string"
    },
    "estado_actual": {
        "motivo_consulta": "string",
        "nivel_urgencia": "bajo | medio | alto | crítico",
        "sintomas": ["string"],
        "ubicacion_actual": {
            "latitud": "float",
            "longitud": "float"
        },
        "hora_reporte": "ISO8601 datetime"
    },
    "preferencias": {
        "idioma_preferido": "español | inglés | francés | alemán | portugués",
        "hospital_preferido": "string",
        "especialista_preferido": "string"
    },
    "asignacion_actual": {
        "hospital_asignado": "string",
        "especialista_asignado": "string",
        "fecha_asignacion": "ISO8601 datetime",
        "estado_asignacion": "pendiente | en proceso | confirmado | completado"
    },
    "notas_personales": "string",
    "historial_chat": [
        {
            "timestamp": "ISO8601 datetime",
            "mensaje_usuario": "string",
            "respuesta_bot": "string"
        }
    ],
    "auditoria": {
        "creado_en": "ISO8601 datetime",
        "actualizado_en": "ISO8601 datetime",
        "creado_por": "admin | sistema | api",
        "ultima_modificacion_por": "admin | sistema | api"
    }
}

# Guardar el archivo JSON
ruta_archivo = Path("/mnt/data/estructura_paciente_compleja.json")
with open(ruta_archivo, "w") as f:
    json.dump(estructura_paciente, f, indent=2)

ruta_archivo
